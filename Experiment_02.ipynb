# %% [markdown]
# <a href="https://colab.research.google.com/github/TejshreeRameshKarande/Deep_Learning/blob/main/Experiment_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras import layers, models, regularizers
import matplotlib.pyplot as plt

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

x_train = x_train.reshape(-1, 28*28) / 255.0
x_test = x_test.reshape(-1, 28*28) / 255.0
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step

# %%
baseline = models.Sequential([
    layers.Dense(256, activation='relu', input_shape=(784,)),
    layers.Dense(128, activation='relu'),
    layers.Dense(10, activation='softmax')
])

baseline.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

history_baseline = baseline.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=10)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.8940 - loss: 0.3574 - val_accuracy: 0.9610 - val_loss: 0.1199
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 21s 6ms/step - accuracy: 0.9734 - loss: 0.0854 - val_accuracy: 0.9759 - val_loss: 0.0817
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9816 - loss: 0.0550 - val_accuracy: 0.9755 - val_loss: 0.0810
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9876 - loss: 0.0389 - val_accuracy: 0.9795 - val_loss: 0.0703
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9896 - loss: 0.0298 - val_accuracy: 0.9744 - val_loss: 0.0967
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9923 - loss: 0.0249 - val_accuracy: 0.9747 - val_loss: 0.0947
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9930 - loss: 0.0209 - val_accuracy: 0.9768 - val_loss: 0.0954
# Epoch 8/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9940 - loss: 0.0197 - val_accuracy: 0.9790 - val_loss: 0.0873
# Epoch 9/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9956 - loss: 0.0134 - val_accuracy: 0.9750 - val_loss: 0.1115
# Epoch 10/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9954 - loss: 0.0143 - val_accuracy: 0.9754 - val_loss: 0.1179

# %%
dropout_model = models.Sequential([
    layers.Dense(256, activation='relu', input_shape=(784,)),
    layers.Dropout(0.5),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(10, activation='softmax')
])

dropout_model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

history_dropout = dropout_model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.7806 - loss: 0.6804 - val_accuracy: 0.9560 - val_loss: 0.1479
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 21s 6ms/step - accuracy: 0.9326 - loss: 0.2387 - val_accuracy: 0.9691 - val_loss: 0.1079
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9484 - loss: 0.1791 - val_accuracy: 0.9714 - val_loss: 0.0952
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.9533 - loss: 0.1599 - val_accuracy: 0.9735 - val_loss: 0.0922
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9558 - loss: 0.1563 - val_accuracy: 0.9732 - val_loss: 0.0886
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 20s 6ms/step - accuracy: 0.9596 - loss: 0.1365 - val_accuracy: 0.9736 - val_loss: 0.0867
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9613 - loss: 0.1294 - val_accuracy: 0.9778 - val_loss: 0.0794
# Epoch 8/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9624 - loss: 0.1272 - val_accuracy: 0.9769 - val_loss: 0.0818
# Epoch 9/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9650 - loss: 0.1183 - val_accuracy: 0.9765 - val_loss: 0.0822
# Epoch 10/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9667 - loss: 0.1100 - val_accuracy: 0.9784 - val_loss: 0.0789

# %%
l2_model = models.Sequential([
    layers.Dense(256, activation='relu', kernel_regularizer=regularizers.l2(0.001), input_shape=(784,)),
    layers.Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.001)),
    layers.Dense(10, activation='softmax')
])

l2_model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

history_l2 = l2_model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - accuracy: 0.8905 - loss: 0.6700 - val_accuracy: 0.9606 - val_loss: 0.2856
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.9586 - loss: 0.2778 - val_accuracy: 0.9672 - val_loss: 0.2298
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.9667 - loss: 0.2267 - val_accuracy: 0.9655 - val_loss: 0.2198
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.9701 - loss: 0.2011 - val_accuracy: 0.9726 - val_loss: 0.1927
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9727 - loss: 0.1826 - val_accuracy: 0.9739 - val_loss: 0.1721
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9741 - loss: 0.1742 - val_accuracy: 0.9719 - val_loss: 0.1777
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.9766 - loss: 0.1644 - val_accuracy: 0.9682 - val_loss: 0.1794
# Epoch 8/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.9753 - loss: 0.1622 - val_accuracy: 0.9716 - val_loss: 0.1677
# Epoch 9/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9766 - loss: 0.1557 - val_accuracy: 0.9721 - val_loss: 0.1750
# Epoch 10/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9759 - loss: 0.1565 - val_accuracy: 0.9728 - val_loss: 0.1728

# %%
bn_model = models.Sequential([
    layers.Dense(256, input_shape=(784,)),
    layers.BatchNormalization(),
    layers.Activation('relu'),

    layers.Dense(128),
    layers.BatchNormalization(),
    layers.Activation('relu'),

    layers.Dense(10, activation='softmax')
])

bn_model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

history_bn = bn_model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 16s 7ms/step - accuracy: 0.8936 - loss: 0.3513 - val_accuracy: 0.9677 - val_loss: 0.1027
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.9690 - loss: 0.0990 - val_accuracy: 0.9740 - val_loss: 0.0820
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9794 - loss: 0.0679 - val_accuracy: 0.9808 - val_loss: 0.0670
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9818 - loss: 0.0549 - val_accuracy: 0.9783 - val_loss: 0.0687
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - accuracy: 0.9851 - loss: 0.0470 - val_accuracy: 0.9802 - val_loss: 0.0641
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9879 - loss: 0.0370 - val_accuracy: 0.9824 - val_loss: 0.0578
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.9902 - loss: 0.0313 - val_accuracy: 0.9811 - val_loss: 0.0642
# Epoch 8/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.9900 - loss: 0.0299 - val_accuracy: 0.9832 - val_loss: 0.0580
# Epoch 9/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9911 - loss: 0.0273 - val_accuracy: 0.9813 - val_loss: 0.0647
# Epoch 10/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9923 - loss: 0.0238 - val_accuracy: 0.9813 - val_loss: 0.0647

# %%
plt.plot(history_baseline.history['val_loss'], label="Baseline")
plt.plot(history_dropout.history['val_loss'], label="Dropout")
plt.plot(history_l2.history['val_loss'], label="L2 Regularization")
plt.plot(history_bn.history['val_loss'], label="Batch Normalization")

plt.title("Validation Loss Comparison")
plt.legend()
plt.show()

# %%
print("Baseline Accuracy:", baseline.evaluate(x_test, y_test)[1])
print("Dropout Accuracy:", dropout_model.evaluate(x_test, y_test)[1])
print("L2 Accuracy:", l2_model.evaluate(x_test, y_test)[1])
print("BatchNorm Accuracy:", bn_model.evaluate(x_test, y_test)[1])
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9711 - loss: 0.1397
# Baseline Accuracy: 0.9753999710083008
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9745 - loss: 0.0917
# Dropout Accuracy: 0.9783999919891357
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9688 - loss: 0.1895
# L2 Accuracy: 0.9728000164031982
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9760 - loss: 0.0796
# BatchNorm Accuracy: 0.9812999963760376
